# %% [markdown]
# MC Simulation, Exercises 7
# =
# Problem 2
# -
# ###(a)
# $F(x) = 1 - e^{-(x/ \beta)^\alpha}$
# ###(b)
# $F^{-1}(z) = \beta (-ln(-z + 1))^{1/\alpha}$
# ###(c)

# %%
N = 10000

a = 1.5
b = 6.0

z = 

Finv = lambda z: b(-log(-z + 1))**(1/a)

xsamples = Finv(z)
# Out:
#   File "<ipython-input-47-449456c4b08a>", line 6
#     z =
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ###(d)

# %%
x = arange(0.0, 20.001, 0.01)
a = 1.5
b = 6.0
f = lambda x: a * b**(-a) * x**(a - 1) * exp(-(x/b)**(a))
F = lambda x: 1 - exp(-(x/b)**a)

plot(x, f(x), label = 'True distribution', lw = 3)
plot(x, F(x), label = 'Cumulative function', lw = 3)
     
xlim(0, 20.1)

legend(loc = 0)
show()

# %% [markdown]
# Problem 3
# -
# ###(a)

# %%
f = lambda x: 60 * x**3 * (1 - x)**2
x = arange(0.0,1.0001,0.001)

xmin = 0
xmax = 1.0

ymax = 2.4
ymin = 0

N = 10000
samples_x = xmin + (xmax - xmin) * random_sample(N);
samples_y = ymin + (ymax - ymin) * random_sample(N);

newmask = (samples_y < f(samples_x))

myplot = plot(x,f(x),lw=3)
xlim(0.0,1.0)

plot(samples_x[1:10000],samples_y[1:10000],'.')

plot(samples_x[newmask[:10000]],samples_y[newmask[:10000]],'.')

plot([xmin, xmin], [ymin, ymax], color = 'k', linestyle = '--') #vertical left
plot([xmax, xmax], [ymin, ymax], color = 'k', linestyle = '--') #vertical right
plot([xmin, xmax], [ymax, ymax], color = 'k', linestyle = '--') #horizontal top

show()

# %% [markdown]
# ###(b)

# %%
f = lambda x: 60 * x**3 * (1 - x)**2
x = arange(0.0,1.0001,0.001)


plot(x, f(x), label = 'True distribution', lw = 3)
legend(loc=2)
show()
