# %% [markdown]
# Tuesday April, 16 Notes
# =

# %% [markdown]
# Using matplotlib to make 3D graphs
# -

# %%
#simple line plot
t = arange(0.0, 1.01, 0.01)
c = cos(4 * pi * t)
s = sin(4 * pi * t)

# %%
print pi
pi = 3.
print pi
# Out:
# 3.14159265359
# 3.0

# %%
pi = np.pi
print pi
# Out:
# 3.14159265359

# %%
plot(t, s, color = "blue", linewidth = 2.5, label = "$sin(4{\pi}t)$")  #default linewidth is 1
plot(t, c, color = "red", linewidth = 2.5, label = "$cos(4{\pi}t)$")
xlabel("time (s)", fontsize = 15)
ylabel("voltage (mV)", fontsize = 15)
title("My Cool Plot", fontsize = 20)  #default value for fontsize is 10
legend() # () means it is in a default location
grid(True)  #lines at major tick marks
savefig("simple_plot.pdf")  #change file type by putting .pdf; creates file of just the graph
show()   #remove code line
#to get Greek letters. ex: \sigma or \Sigma (capital)
